# %%
#asteroide_acecino 
a=45
if a <= 20:
    print("La velocidad es:", a, " todo esta bien" )
else :
    print("La velocida es:",a,"CORREEEEEEEEEEEEE")
# Out:
# La velocida es: 45 CORREEEEEEEEEEEEE

# %%
a=20
if a > 20:
    print("Voltea al cielo, veras una luz brillante")
elif a==20:
    print("Voltea al cielo , veras una luz tenue")
else:
    print("Nada que ver")
# Out:
# Voltea al cielo , veras una luz tenue

# %%
v_a = 20
t_a = 40
if v_a > 25 and t_a > 25:
    print("Vamos a morir :(")
elif v_a >= 20:
    print("Luces en el cielo")
elif t_a < 25:
    print("Todo normal")
else:
    print("Todo normal")
# Out:
# Luces en el cielo
