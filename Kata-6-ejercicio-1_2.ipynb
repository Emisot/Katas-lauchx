# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']

print('There are', len(planets), 'planets')
# Agregamos a plutón y mostramos el último elemento

planets.append('Pluto')

print(planets[-1], 'is the last planet')
# Out:
# There are 8 planets
# Pluto is the last planet

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune']

user_planet = input('Please enter the name of the planet (with a capital letter to start)')


planet_index = planets.index(user_planet)


print('Here are the planets closer than ' + user_planet)
print(planets[0:planet_index])

print('Here are the planets further than ' + user_planet)
print(planets[planet_index + 1:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-1.ipynb Cell 2' in <module>
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000001untitled?line=4'>5</a> user_planet = input('Please enter the name of the planet (with a capital letter to start)')
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000001untitled?line=5'>6</a> # Busca el planeta en la lista
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000001untitled?line=7'>8</a> planet_index = planets.index(user_planet)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000001untitled?line=8'>9</a> # Muestra los planetas más cercanos al sol
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000001untitled?line=10'>11</a> print('Here are the planets closer than ' + user_planet)
#
# ValueError: '1' is not in list
