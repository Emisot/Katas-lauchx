# %%
planeta = 'Marte '
gravedad  = 0.00143
nombre = 'Ganímedes'

# %%
title = f'datos de gravedad sobre {nombre}'

# %%
hechos = f"""{'-'*80} 
Nombre del planeta: {planeta} 
Gravedad en {nombre}: {gravedad * 1000} m/s2 
"""

# %%
template = f"""{title.title()} 
{hechos} 
""" 
print(hechos)
# Out:
# --------------------------------------------------------------------------------
# Nombre del planeta: Marte
# Gravedad en Ganímedes: 1.4300000000000002 m/s2

# %%
planeta = 'Marte '
gravedad  = 0.00143
nombre = 'Ganímedes'

# %%
print(hechos)
# Out:
# --------------------------------------------------------------------------------
# Nombre del planeta: Marte
# Gravedad en Ganímedes: 1.4300000000000002 m/s2

# %%
print(new_template.format(nombre=nombre, planeta=planeta, gravedad=gravedad))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-2.ipynb Cell 7' in <module>
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#ch0000007untitled?line=0'>1</a> print(new_template.format(nombre=nombre, planeta=planeta, gravedad=gravedad))
#
# NameError: name 'new_template' is not defined

# %%
print(new_template.format(nombre=nombre, planeta=planeta, gravedad=gravedad*1000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-2.ipynb Cell 7' in <module>
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#ch0000006untitled?line=0'>1</a> print(new_template.format(nombre=nombre, planeta=planeta, gravedad=gravedad*1000))
#
# NameError: name 'new_template' is not defined
